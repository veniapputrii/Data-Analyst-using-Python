# %% [markdown]
# <a href="https://colab.research.google.com/github/veniapputrii/Data-Analyst-using-Python/blob/main/kleinesProojekt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
# !kaggle datasets download -d sijovm/used-cars-data-from-ebay-kleinanzeigen
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sijovm/used-cars-data-from-ebay-kleinanzeigen
# License(s): CC0-1.0
# used-cars-data-from-ebay-kleinanzeigen.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !mkdir Dataset
# !cp /content/drive/MyDrive/Kaggle/used-cars-data-from-ebay-kleinanzeigen.zip /content/Dataset/used-cars-data-from-ebay-kleinanzeigen.zip
# !unzip -q /content/Dataset/used-cars-data-from-ebay-kleinanzeigen.zip -d /content/Dataset
# !rm /content/Dataset/used-cars-data-from-ebay-kleinanzeigen.zip
# Out:
# mkdir: cannot create directory ‘Dataset’: File exists
# cp: cannot stat '/content/drive/MyDrive/Kaggle/used-cars-data-from-ebay-kleinanzeigen.zip': No such file or directory
# unzip:  cannot find or open /content/Dataset/used-cars-data-from-ebay-kleinanzeigen.zip, /content/Dataset/used-cars-data-from-ebay-kleinanzeigen.zip.zip or /content/Dataset/used-cars-data-from-ebay-kleinanzeigen.zip.ZIP.
# rm: cannot remove '/content/Dataset/used-cars-data-from-ebay-kleinanzeigen.zip': No such file or directory

# %%
import kagglehub


# Download latest version
path = kagglehub.dataset_download("sijovm/used-cars-data-from-ebay-kleinanzeigen")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/sijovm/used-cars-data-from-ebay-kleinanzeigen/versions/1
