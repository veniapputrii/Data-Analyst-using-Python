# %% [markdown]
# <a href="https://colab.research.google.com/github/veniapputrii/Data-Analyst-using-Python/blob/main/kleinesProojekt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sijovm/used-cars-data-from-ebay-kleinanzeigen")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 17.2M/17.2M [00:00<00:00, 136MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/sijovm/used-cars-data-from-ebay-kleinanzeigen/versions/1
